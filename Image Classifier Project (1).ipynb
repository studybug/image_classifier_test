# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %config IPCompleter.greedy=True
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt
import os, random
import json
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, transforms, models
from collections import OrderedDict
from PIL import Image
import time

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
image_datasets = datasets.ImageFolder(data_dir, transform=data_transforms)
train_data = datasets.ImageFolder(train_dir, transform=data_transforms)
valid_data = datasets.ImageFolder(valid_dir, transform=data_transforms)
test_data = datasets.ImageFolder(test_dir , transform=data_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
#dataloaders = torch.utils.data.DataLoader(image_datasets, batch_size=64, shuffle=True)
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(valid_data, batch_size=64, shuffle=True)

image_datasets = [train_data, valid_data, test_data]
dataloaders = [trainloader, validloader, testloader]

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

print(cat_to_name)
print("\n Length:", len(cat_to_name))
# Out:
# {'21': 'fire lily', '3': 'canterbury bells', '45': 'bolero deep blue', '1': 'pink primrose', '34': 'mexican aster', '27': 'prince of wales feathers', '7': 'moon orchid', '16': 'globe-flower', '25': 'grape hyacinth', '26': 'corn poppy', '79': 'toad lily', '39': 'siam tulip', '24': 'red ginger', '67': 'spring crocus', '35': 'alpine sea holly', '32': 'garden phlox', '10': 'globe thistle', '6': 'tiger lily', '93': 'ball moss', '33': 'love in the mist', '9': 'monkshood', '102': 'blackberry lily', '14': 'spear thistle', '19': 'balloon flower', '100': 'blanket flower', '13': 'king protea', '49': 'oxeye daisy', '15': 'yellow iris', '61': 'cautleya spicata', '31': 'carnation', '64': 'silverbush', '68': 'bearded iris', '63': 'black-eyed susan', '69': 'windflower', '62': 'japanese anemone', '20': 'giant white arum lily', '38': 'great masterwort', '4': 'sweet pea', '86': 'tree mallow', '101': 'trumpet creeper', '42': 'daffodil', '22': 'pincushion flower', '2': 'hard-leaved pocket orchid', '54': 'sunflower', '66': 'osteospermum', '70': 'tree poppy', '85': 'desert-rose', '99': 'bromelia', '87': 'magnolia', '5': 'english marigold', '92': 'bee balm', '28': 'stemless gentian', '97': 'mallow', '57': 'gaura', '40': 'lenten rose', '47': 'marigold', '59': 'orange dahlia', '48': 'buttercup', '55': 'pelargonium', '36': 'ruby-lipped cattleya', '91': 'hippeastrum', '29': 'artichoke', '71': 'gazania', '90': 'canna lily', '18': 'peruvian lily', '98': 'mexican petunia', '8': 'bird of paradise', '30': 'sweet william', '17': 'purple coneflower', '52': 'wild pansy', '84': 'columbine', '12': "colt's foot", '11': 'snapdragon', '96': 'camellia', '23': 'fritillary', '50': 'common dandelion', '44': 'poinsettia', '53': 'primula', '72': 'azalea', '65': 'californian poppy', '80': 'anthurium', '76': 'morning glory', '37': 'cape flower', '56': 'bishop of llandaff', '60': 'pink-yellow dahlia', '82': 'clematis', '58': 'geranium', '75': 'thorn apple', '41': 'barbeton daisy', '95': 'bougainvillea', '43': 'sword lily', '83': 'hibiscus', '78': 'lotus lotus', '88': 'cyclamen', '94': 'foxglove', '81': 'frangipani', '74': 'rose', '89': 'watercress', '73': 'water lily', '46': 'wallflower', '77': 'passion flower', '51': 'petunia'}
#
#  Length: 102

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
# Load a pre-trained network
# Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout

import torchvision.models as models
model = models.vgg19(pretrained=True)
model

for param in model.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.torch/models/vgg19-dcbb9e9d.pth
# 100%|██████████| 574673361/574673361 [00:25<00:00, 22693721.86it/s]

# %%
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(25088, 500)),
                            ('drop', nn.Dropout(p=0.5)),
                          ('relu', nn.ReLU()),
                          ('fc2', nn.Linear(500, 102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
model.classifier = classifier
#print(model)

# %%
# Cuda to CPU recognition:
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=500, bias=True)
#     (drop): Dropout(p=0.5)
#     (relu): ReLU()
#     (fc2): Linear(in_features=500, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
print(type(images))
print(images.shape)
print(labels.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([64, 3, 224, 224])
# torch.Size([64])

# %%
# flatten the input images
#class Flatten(nn.Module):
    #def forward(self, input):
        #return input.view(input.size(0), -1)

#def activation(x): #defining sigmoid activation func we knew part1
    #return 1/(1+torch.exp(-x))
        
#input_images = images.view(images.shape[0], -1)

#activation(torch.nn(input_images))

# %%
# Train the classifier layers using backpropagation using the pre-trained network to get the features.
# Track the loss and accuracy on the validation set to determine the best hyperparameters.
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.classifier.parameters(), lr=0.01)

epochs = 8
steps = 0
cuda = torch.cuda.is_available()

running_loss = 0
accuracy = 0

print_every= 40

start = time.time()
print('Training started')

for e in range(epochs):
    train_m = 0
    valid_m = 1

    # Each epoch has a training and validation phase
    for mode in [train_m, valid_m]:
        if mode == train_m:
            model.train()
        else:
            model.eval()
        
        pass_count = 0
        
        for data in dataloaders[mode]:
            pass_count += 1
            inputs, labels = data
        
            inputs, labels = inputs.to(device), labels.to(device)
                

            optimizer.zero_grad()
            # forward
            output = model.forward(inputs)
            loss = criterion(output, labels)
            # only backward with train
            if mode == train_m:
                loss.backward()
                optimizer.step()

            # calculate accuracy
            running_loss += loss.item()
            ps = torch.exp(output).data
            equality = (labels.data == ps.max(1)[1])
            accuracy = equality.type_as(torch.cuda.FloatTensor()).mean()

            if mode == train_m:
                print("\nEpoch: {}/{} ".format(e + 1, epochs),
                          "\nTraining Loss: {:.4f}  ".format(running_loss / pass_count))
            else:
                print("Validation Loss: {:.4f}  ".format(running_loss / pass_count),
                          "Accuracy: {:.4f}".format(accuracy))

            running_loss = 0
            
                
time_elapsed = time.time() - start
print("\nTotal time: {:.0f}m {:.0f}s".format(time_elapsed//60, time_elapsed % 60))
# Out:
# Training started
#
# Epoch: 1/8
# Training Loss: 4.7522
#
# Epoch: 1/8
# Training Loss: 2.3193
#
# Epoch: 1/8
# Training Loss: 1.5512
#
# Epoch: 1/8
# Training Loss: 1.1511
#
# Epoch: 1/8
# Training Loss: 0.9248
#
# Epoch: 1/8
# Training Loss: 0.7502
#
# Epoch: 1/8
# Training Loss: 0.6563
#
# Epoch: 1/8
# Training Loss: 0.5729
#
# Epoch: 1/8
# Training Loss: 0.5061
#
# Epoch: 1/8
# Training Loss: 0.4513
#
# Epoch: 1/8
# Training Loss: 0.4134
#
# Epoch: 1/8
# Training Loss: 0.3744
#
# Epoch: 1/8
# Training Loss: 0.3539
#
# Epoch: 1/8
# Training Loss: 0.3261
#
# Epoch: 1/8
# Training Loss: 0.2941
#
# Epoch: 1/8
# Training Loss: 0.2829
#
# Epoch: 1/8
# Training Loss: 0.2580
#
# Epoch: 1/8
# Training Loss: 0.2440
#
# Epoch: 1/8
# Training Loss: 0.2249
#
# Epoch: 1/8
# Training Loss: 0.2223
#
# Epoch: 1/8
# Training Loss: 0.2116
#
# Epoch: 1/8
# Training Loss: 0.2017
#
# Epoch: 1/8
# Training Loss: 0.1915
#
# Epoch: 1/8
# Training Loss: 0.1818
#
# Epoch: 1/8
# Training Loss: 0.1732
#
# Epoch: 1/8
# Training Loss: 0.1742
#
# Epoch: 1/8
# Training Loss: 0.1573
#
# Epoch: 1/8
# Training Loss: 0.1528
#
# Epoch: 1/8
# Training Loss: 0.1415
#
# Epoch: 1/8
# Training Loss: 0.1446
#
# Epoch: 1/8
# Training Loss: 0.1346
#
# Epoch: 1/8
# Training Loss: 0.1307
#
# Epoch: 1/8
# Training Loss: 0.1205
#
# Epoch: 1/8
# Training Loss: 0.1256
#
# Epoch: 1/8
# Training Loss: 0.1248
#
# Epoch: 1/8
# Training Loss: 0.1157
#
# Epoch: 1/8
# Training Loss: 0.1119
#
# Epoch: 1/8
# Training Loss: 0.1063
#
# Epoch: 1/8
# Training Loss: 0.1021
#
# Epoch: 1/8
# Training Loss: 0.1008
#
# Epoch: 1/8
# Training Loss: 0.0971
#
# Epoch: 1/8
# Training Loss: 0.0970
#
# Epoch: 1/8
# Training Loss: 0.0961
#
# Epoch: 1/8
# Training Loss: 0.0935
#
# Epoch: 1/8
# Training Loss: 0.0933
#
# Epoch: 1/8
# Training Loss: 0.0861
#
# Epoch: 1/8
# Training Loss: 0.0885
#
# Epoch: 1/8
# Training Loss: 0.0824
#
# Epoch: 1/8
# Training Loss: 0.0850
#
# Epoch: 1/8
# Training Loss: 0.0824
#
# Epoch: 1/8
# Training Loss: 0.0748
#
# Epoch: 1/8
# Training Loss: 0.0735
#
# Epoch: 1/8
# Training Loss: 0.0737
#
# Epoch: 1/8
# Training Loss: 0.0739
#
# Epoch: 1/8
# Training Loss: 0.0671
#
# Epoch: 1/8
# Training Loss: 0.0690
#
# Epoch: 1/8
# Training Loss: 0.0674
#
# Epoch: 1/8
# Training Loss: 0.0663
#
# Epoch: 1/8
# Training Loss: 0.0670
#
# Epoch: 1/8
# Training Loss: 0.0645
#
# Epoch: 1/8
# Training Loss: 0.0629
#
# Epoch: 1/8
# Training Loss: 0.0648
#
# Epoch: 1/8
# Training Loss: 0.0636
#
# Epoch: 1/8
# Training Loss: 0.0627
#
# Epoch: 1/8
# Training Loss: 0.0594
#
# Epoch: 1/8
# Training Loss: 0.0575
#
# Epoch: 1/8
# Training Loss: 0.0575
#
# Epoch: 1/8
# Training Loss: 0.0549
#
# Epoch: 1/8
# Training Loss: 0.0562
#
# Epoch: 1/8
# Training Loss: 0.0488
#
# Epoch: 1/8
# Training Loss: 0.0545
#
# Epoch: 1/8
# Training Loss: 0.0497
#
# Epoch: 1/8
# Training Loss: 0.0472
#
# Epoch: 1/8
# Training Loss: 0.0478
#
# Epoch: 1/8
# Training Loss: 0.0472
#
# Epoch: 1/8
# Training Loss: 0.0486
#
# Epoch: 1/8
# Training Loss: 0.0460
#
# Epoch: 1/8
# Training Loss: 0.0438
#
# Epoch: 1/8
# Training Loss: 0.0458
#
# Epoch: 1/8
# Training Loss: 0.0433
#
# Epoch: 1/8
# Training Loss: 0.0409
#
# Epoch: 1/8
# Training Loss: 0.0444
#
# Epoch: 1/8
# Training Loss: 0.0423
#
# Epoch: 1/8
# Training Loss: 0.0409
#
# Epoch: 1/8
# Training Loss: 0.0396
#
# Epoch: 1/8
# Training Loss: 0.0429
#
# Epoch: 1/8
# Training Loss: 0.0394
#
# Epoch: 1/8
# Training Loss: 0.0408
#
# Epoch: 1/8
# Training Loss: 0.0378
#
# Epoch: 1/8
# Training Loss: 0.0367
#
# Epoch: 1/8
# Training Loss: 0.0423
#
# Epoch: 1/8
# Training Loss: 0.0369
#
# Epoch: 1/8
# Training Loss: 0.0362
#
# Epoch: 1/8
# Training Loss: 0.0359
#
# Epoch: 1/8
# Training Loss: 0.0349
#
# Epoch: 1/8
# Training Loss: 0.0360
#
# Epoch: 1/8
# Training Loss: 0.0337
#
# Epoch: 1/8
# Training Loss: 0.0325
#
# Epoch: 1/8
# Training Loss: 0.0360
#
# Epoch: 1/8
# Training Loss: 0.0311
#
# Epoch: 1/8
# Training Loss: 0.0308
#
# Epoch: 1/8
# Training Loss: 0.0327
#
# Epoch: 1/8
# Training Loss: 0.0295
# Validation Loss: 3.1329   Accuracy: 0.3750
# Validation Loss: 1.6267   Accuracy: 0.2969
# Validation Loss: 0.9761   Accuracy: 0.5000
# Validation Loss: 0.8008   Accuracy: 0.2969
# Validation Loss: 0.6773   Accuracy: 0.2188
# Validation Loss: 0.5595   Accuracy: 0.2812
# Validation Loss: 0.4667   Accuracy: 0.2188
# Validation Loss: 0.3799   Accuracy: 0.2812
# Validation Loss: 0.3424   Accuracy: 0.4062
# Validation Loss: 0.3352   Accuracy: 0.2031
# Validation Loss: 0.2843   Accuracy: 0.3125
# Validation Loss: 0.2564   Accuracy: 0.3438
# Validation Loss: 0.2159   Accuracy: 0.3400
#
# Epoch: 2/8
# Training Loss: 3.4525
#
# Epoch: 2/8
# Training Loss: 1.6172
#
# Epoch: 2/8
# Training Loss: 1.1832
#
# Epoch: 2/8
# Training Loss: 0.8521
#
# Epoch: 2/8
# Training Loss: 0.6029
#
# Epoch: 2/8
# Training Loss: 0.5317
#
# Epoch: 2/8
# Training Loss: 0.4194
#
# Epoch: 2/8
# Training Loss: 0.3939
#
# Epoch: 2/8
# Training Loss: 0.3565
#
# Epoch: 2/8
# Training Loss: 0.3384
#
# Epoch: 2/8
# Training Loss: 0.3077
#
# Epoch: 2/8
# Training Loss: 0.2554
#
# Epoch: 2/8
# Training Loss: 0.2783
#
# Epoch: 2/8
# Training Loss: 0.2298
#
# Epoch: 2/8
# Training Loss: 0.2044
#
# Epoch: 2/8
# Training Loss: 0.2054
#
# Epoch: 2/8
# Training Loss: 0.1961
#
# Epoch: 2/8
# Training Loss: 0.1631
#
# Epoch: 2/8
# Training Loss: 0.1660
#
# Epoch: 2/8
# Training Loss: 0.1570
#
# Epoch: 2/8
# Training Loss: 0.1433
#
# Epoch: 2/8
# Training Loss: 0.1381
#
# Epoch: 2/8
# Training Loss: 0.1254
#
# Epoch: 2/8
# Training Loss: 0.1275
#
# Epoch: 2/8
# Training Loss: 0.1277
#
# Epoch: 2/8
# Training Loss: 0.1235
#
# Epoch: 2/8
# Training Loss: 0.1080
#
# Epoch: 2/8
# Training Loss: 0.1081
#
# Epoch: 2/8
# Training Loss: 0.1115
#
# Epoch: 2/8
# Training Loss: 0.1014
#
# Epoch: 2/8
# Training Loss: 0.0983
#
# Epoch: 2/8
# Training Loss: 0.0926
#
# Epoch: 2/8
# Training Loss: 0.0846
#
# Epoch: 2/8
# Training Loss: 0.0852
#
# Epoch: 2/8
# Training Loss: 0.0870
#
# Epoch: 2/8
# Training Loss: 0.0829
#
# Epoch: 2/8
# Training Loss: 0.0836
#
# Epoch: 2/8
# Training Loss: 0.0735
#
# Epoch: 2/8
# Training Loss: 0.0815
#
# Epoch: 2/8
# Training Loss: 0.0713
#
# Epoch: 2/8
# Training Loss: 0.0653
#
# Epoch: 2/8
# Training Loss: 0.0708
#
# Epoch: 2/8
# Training Loss: 0.0739
#
# Epoch: 2/8
# Training Loss: 0.0645
#
# Epoch: 2/8
# Training Loss: 0.0646
#
# Epoch: 2/8
# Training Loss: 0.0692
#
# Epoch: 2/8
# Training Loss: 0.0559
#
# Epoch: 2/8
# Training Loss: 0.0623
#
# Epoch: 2/8
# Training Loss: 0.0586
#
# Epoch: 2/8
# Training Loss: 0.0579
#
# Epoch: 2/8
# Training Loss: 0.0515
#
# Epoch: 2/8
# Training Loss: 0.0487
#
# Epoch: 2/8
# Training Loss: 0.0511
#
# Epoch: 2/8
# Training Loss: 0.0475
#
# Epoch: 2/8
# Training Loss: 0.0450
#
# Epoch: 2/8
# Training Loss: 0.0466
#
# Epoch: 2/8
# Training Loss: 0.0513
#
# Epoch: 2/8
# Training Loss: 0.0434
#
# Epoch: 2/8
# Training Loss: 0.0466
#
# Epoch: 2/8
# Training Loss: 0.0439
#
# Epoch: 2/8
# Training Loss: 0.0497
#
# Epoch: 2/8
# Training Loss: 0.0469
#
# Epoch: 2/8
# Training Loss: 0.0433
#
# Epoch: 2/8
# Training Loss: 0.0412
#
# Epoch: 2/8
# Training Loss: 0.0482
#
# Epoch: 2/8
# Training Loss: 0.0386
#
# Epoch: 2/8
# Training Loss: 0.0415
#
# Epoch: 2/8
# Training Loss: 0.0412
#
# Epoch: 2/8
# Training Loss: 0.0427
#
# Epoch: 2/8
# Training Loss: 0.0341
#
# Epoch: 2/8
# Training Loss: 0.0415
#
# Epoch: 2/8
# Training Loss: 0.0400
#
# Epoch: 2/8
# Training Loss: 0.0415
#
# Epoch: 2/8
# Training Loss: 0.0315
#
# Epoch: 2/8
# Training Loss: 0.0350
#
# Epoch: 2/8
# Training Loss: 0.0359
#
# Epoch: 2/8
# Training Loss: 0.0337
#
# Epoch: 2/8
# Training Loss: 0.0325
#
# Epoch: 2/8
# Training Loss: 0.0346
#
# Epoch: 2/8
# Training Loss: 0.0354
#
# Epoch: 2/8
# Training Loss: 0.0335
#
# Epoch: 2/8
# Training Loss: 0.0306
#
# Epoch: 2/8
# Training Loss: 0.0305
#
# Epoch: 2/8
# Training Loss: 0.0330
#
# Epoch: 2/8
# Training Loss: 0.0308
#
# Epoch: 2/8
# Training Loss: 0.0312
#
# Epoch: 2/8
# Training Loss: 0.0264
#
# Epoch: 2/8
# Training Loss: 0.0301
#
# Epoch: 2/8
# Training Loss: 0.0273
#
# Epoch: 2/8
# Training Loss: 0.0284
#
# Epoch: 2/8
# Training Loss: 0.0287
#
# Epoch: 2/8
# Training Loss: 0.0293
#
# Epoch: 2/8
# Training Loss: 0.0277
#
# Epoch: 2/8
# Training Loss: 0.0257
#
# Epoch: 2/8
# Training Loss: 0.0246
#
# Epoch: 2/8
# Training Loss: 0.0266
#
# Epoch: 2/8
# Training Loss: 0.0248
#
# Epoch: 2/8
# Training Loss: 0.0258
#
# Epoch: 2/8
# Training Loss: 0.0248
#
# Epoch: 2/8
# Training Loss: 0.0249
#
# Epoch: 2/8
# Training Loss: 0.0220
#
# Epoch: 2/8
# Training Loss: 0.0253
#
# Epoch: 2/8
# Training Loss: 0.0279
# Validation Loss: 2.3039   Accuracy: 0.5156
# Validation Loss: 1.2040   Accuracy: 0.4688
# Validation Loss: 0.8227   Accuracy: 0.4219
# Validation Loss: 0.5693   Accuracy: 0.4688
# Validation Loss: 0.4131   Accuracy: 0.5156
# Validation Loss: 0.3560   Accuracy: 0.5938
# Validation Loss: 0.3040   Accuracy: 0.5312
# Validation Loss: 0.3188   Accuracy: 0.4219
# Validation Loss: 0.2615   Accuracy: 0.4375
# Validation Loss: 0.2294   Accuracy: 0.4688
# Validation Loss: 0.2069   Accuracy: 0.4688
# Validation Loss: 0.1877   Accuracy: 0.4531
# Validation Loss: 0.1870   Accuracy: 0.4400
#
# Epoch: 3/8
# Training Loss: 2.6033
#
# Epoch: 3/8
# Training Loss: 1.2741
#
# Epoch: 3/8
# Training Loss: 0.7586
#
# Epoch: 3/8
# Training Loss: 0.6630
#
# Epoch: 3/8
# Training Loss: 0.4639
#
# Epoch: 3/8
# Training Loss: 0.3987
#
# Epoch: 3/8
# Training Loss: 0.3462
#
# Epoch: 3/8
# Training Loss: 0.2627
#
# Epoch: 3/8
# Training Loss: 0.2561
#
# Epoch: 3/8
# Training Loss: 0.2641
#
# Epoch: 3/8
# Training Loss: 0.2200
#
# Epoch: 3/8
# Training Loss: 0.2233
#
# Epoch: 3/8
# Training Loss: 0.1912
#
# Epoch: 3/8
# Training Loss: 0.1795
#
# Epoch: 3/8
# Training Loss: 0.1375
#
# Epoch: 3/8
# Training Loss: 0.1407
#
# Epoch: 3/8
# Training Loss: 0.1251
#
# Epoch: 3/8
# Training Loss: 0.1252
#
# Epoch: 3/8
# Training Loss: 0.1108
#
# Epoch: 3/8
# Training Loss: 0.1171
#
# Epoch: 3/8
# Training Loss: 0.1268
#
# Epoch: 3/8
# Training Loss: 0.1006
#
# Epoch: 3/8
# Training Loss: 0.1106
#
# Epoch: 3/8
# Training Loss: 0.0887
#
# Epoch: 3/8
# Training Loss: 0.0827
#
# Epoch: 3/8
# Training Loss: 0.0946
#
# Epoch: 3/8
# Training Loss: 0.0920
#
# Epoch: 3/8
# Training Loss: 0.0718
#
# Epoch: 3/8
# Training Loss: 0.0745
#
# Epoch: 3/8
# Training Loss: 0.0809
#
# Epoch: 3/8
# Training Loss: 0.0670
#
# Epoch: 3/8
# Training Loss: 0.0759
#
# Epoch: 3/8
# Training Loss: 0.0734
#
# Epoch: 3/8
# Training Loss: 0.0842
#
# Epoch: 3/8
# Training Loss: 0.0641
#
# Epoch: 3/8
# Training Loss: 0.0692
#
# Epoch: 3/8
# Training Loss: 0.0595
#
# Epoch: 3/8
# Training Loss: 0.0602
#
# Epoch: 3/8
# Training Loss: 0.0580
#
# Epoch: 3/8
# Training Loss: 0.0555
#
# Epoch: 3/8
# Training Loss: 0.0555
#
# Epoch: 3/8
# Training Loss: 0.0660
#
# Epoch: 3/8
# Training Loss: 0.0542
#
# Epoch: 3/8
# Training Loss: 0.0535
#
# Epoch: 3/8
# Training Loss: 0.0507
#
# Epoch: 3/8
# Training Loss: 0.0474
#
# Epoch: 3/8
# Training Loss: 0.0493
#
# Epoch: 3/8
# Training Loss: 0.0451
#
# Epoch: 3/8
# Training Loss: 0.0473
#
# Epoch: 3/8
# Training Loss: 0.0474
#
# Epoch: 3/8
# Training Loss: 0.0348
#
# Epoch: 3/8
# Training Loss: 0.0410
#
# Epoch: 3/8
# Training Loss: 0.0459
#
# Epoch: 3/8
# Training Loss: 0.0392
#
# Epoch: 3/8
# Training Loss: 0.0427
#
# Epoch: 3/8
# Training Loss: 0.0473
#
# Epoch: 3/8
# Training Loss: 0.0419
#
# Epoch: 3/8
# Training Loss: 0.0381
#
# Epoch: 3/8
# Training Loss: 0.0320
#
# Epoch: 3/8
# Training Loss: 0.0377
#
# Epoch: 3/8
# Training Loss: 0.0329
#
# Epoch: 3/8
# Training Loss: 0.0317
#
# Epoch: 3/8
# Training Loss: 0.0371
#
# Epoch: 3/8
# Training Loss: 0.0321
#
# Epoch: 3/8
# Training Loss: 0.0358
#
# Epoch: 3/8
# Training Loss: 0.0350
#
# Epoch: 3/8
# Training Loss: 0.0251
#
# Epoch: 3/8
# Training Loss: 0.0341
#
# Epoch: 3/8
# Training Loss: 0.0314
#
# Epoch: 3/8
# Training Loss: 0.0294
#
# Epoch: 3/8
# Training Loss: 0.0286
#
# Epoch: 3/8
# Training Loss: 0.0280
#
# Epoch: 3/8
# Training Loss: 0.0298
#
# Epoch: 3/8
# Training Loss: 0.0286
#
# Epoch: 3/8
# Training Loss: 0.0303
#
# Epoch: 3/8
# Training Loss: 0.0262
#
# Epoch: 3/8
# Training Loss: 0.0280
#
# Epoch: 3/8
# Training Loss: 0.0277
#
# Epoch: 3/8
# Training Loss: 0.0256
#
# Epoch: 3/8
# Training Loss: 0.0256
#
# Epoch: 3/8
# Training Loss: 0.0233
#
# Epoch: 3/8
# Training Loss: 0.0310
#
# Epoch: 3/8
# Training Loss: 0.0232
#
# Epoch: 3/8
# Training Loss: 0.0250
#
# Epoch: 3/8
# Training Loss: 0.0242
#
# Epoch: 3/8
# Training Loss: 0.0255
#
# Epoch: 3/8
# Training Loss: 0.0229
#
# Epoch: 3/8
# Training Loss: 0.0234
#
# Epoch: 3/8
# Training Loss: 0.0239
#
# Epoch: 3/8
# Training Loss: 0.0256
#
# Epoch: 3/8
# Training Loss: 0.0227
#
# Epoch: 3/8
# Training Loss: 0.0212
#
# Epoch: 3/8
# Training Loss: 0.0195
#
# Epoch: 3/8
# Training Loss: 0.0212
#
# Epoch: 3/8
# Training Loss: 0.0203
#
# Epoch: 3/8
# Training Loss: 0.0205
#
# Epoch: 3/8
# Training Loss: 0.0223
#
# Epoch: 3/8
# Training Loss: 0.0198
#
# Epoch: 3/8
# Training Loss: 0.0238
#
# Epoch: 3/8
# Training Loss: 0.0165
#
# Epoch: 3/8
# Training Loss: 0.0205
#
# Epoch: 3/8
# Training Loss: 0.0155
#
# Epoch: 3/8
# Training Loss: 0.0172
# Validation Loss: 1.6474   Accuracy: 0.7188
# Validation Loss: 1.0153   Accuracy: 0.5625
# Validation Loss: 0.6258   Accuracy: 0.5156
# Validation Loss: 0.4532   Accuracy: 0.6406
# Validation Loss: 0.3759   Accuracy: 0.5625
# Validation Loss: 0.2959   Accuracy: 0.6406
# Validation Loss: 0.2009   Accuracy: 0.6719
# Validation Loss: 0.2304   Accuracy: 0.5938
# Validation Loss: 0.1997   Accuracy: 0.6406
# Validation Loss: 0.1716   Accuracy: 0.6562
# Validation Loss: 0.1536   Accuracy: 0.6406
# Validation Loss: 0.1214   Accuracy: 0.7031
# Validation Loss: 0.1522   Accuracy: 0.5400
#
# Epoch: 4/8
# Training Loss: 2.1606
#
# Epoch: 4/8
# Training Loss: 1.0206
#
# Epoch: 4/8
# Training Loss: 0.7680
#
# Epoch: 4/8
# Training Loss: 0.5514
#
# Epoch: 4/8
# Training Loss: 0.3861
#
# Epoch: 4/8
# Training Loss: 0.3324
#
# Epoch: 4/8
# Training Loss: 0.3075
#
# Epoch: 4/8
# Training Loss: 0.2539
#
# Epoch: 4/8
# Training Loss: 0.2066
#
# Epoch: 4/8
# Training Loss: 0.1906
#
# Epoch: 4/8
# Training Loss: 0.2021
#
# Epoch: 4/8
# Training Loss: 0.1504
#
# Epoch: 4/8
# Training Loss: 0.1604
#
# Epoch: 4/8
# Training Loss: 0.1271
#
# Epoch: 4/8
# Training Loss: 0.1220
#
# Epoch: 4/8
# Training Loss: 0.1125
#
# Epoch: 4/8
# Training Loss: 0.1185
#
# Epoch: 4/8
# Training Loss: 0.1099
#
# Epoch: 4/8
# Training Loss: 0.0962
#
# Epoch: 4/8
# Training Loss: 0.1069
#
# Epoch: 4/8
# Training Loss: 0.1002
#
# Epoch: 4/8
# Training Loss: 0.0842
#
# Epoch: 4/8
# Training Loss: 0.0766
#
# Epoch: 4/8
# Training Loss: 0.0901
#
# Epoch: 4/8
# Training Loss: 0.0674
#
# Epoch: 4/8
# Training Loss: 0.0755
#
# Epoch: 4/8
# Training Loss: 0.0676
#
# Epoch: 4/8
# Training Loss: 0.0700
#
# Epoch: 4/8
# Training Loss: 0.0638
#
# Epoch: 4/8
# Training Loss: 0.0682
#
# Epoch: 4/8
# Training Loss: 0.0588
#
# Epoch: 4/8
# Training Loss: 0.0484
#
# Epoch: 4/8
# Training Loss: 0.0545
#
# Epoch: 4/8
# Training Loss: 0.0456
#
# Epoch: 4/8
# Training Loss: 0.0471
#
# Epoch: 4/8
# Training Loss: 0.0535
#
# Epoch: 4/8
# Training Loss: 0.0601
#
# Epoch: 4/8
# Training Loss: 0.0509
#
# Epoch: 4/8
# Training Loss: 0.0470
#
# Epoch: 4/8
# Training Loss: 0.0462
#
# Epoch: 4/8
# Training Loss: 0.0493
#
# Epoch: 4/8
# Training Loss: 0.0441
#
# Epoch: 4/8
# Training Loss: 0.0455
#
# Epoch: 4/8
# Training Loss: 0.0490
#
# Epoch: 4/8
# Training Loss: 0.0377
#
# Epoch: 4/8
# Training Loss: 0.0413
#
# Epoch: 4/8
# Training Loss: 0.0369
#
# Epoch: 4/8
# Training Loss: 0.0319
#
# Epoch: 4/8
# Training Loss: 0.0378
#
# Epoch: 4/8
# Training Loss: 0.0324
#
# Epoch: 4/8
# Training Loss: 0.0345
#
# Epoch: 4/8
# Training Loss: 0.0362
#
# Epoch: 4/8
# Training Loss: 0.0337
#
# Epoch: 4/8
# Training Loss: 0.0347
#
# Epoch: 4/8
# Training Loss: 0.0418
#
# Epoch: 4/8
# Training Loss: 0.0360
#
# Epoch: 4/8
# Training Loss: 0.0381
#
# Epoch: 4/8
# Training Loss: 0.0372
#
# Epoch: 4/8
# Training Loss: 0.0247
#
# Epoch: 4/8
# Training Loss: 0.0257
#
# Epoch: 4/8
# Training Loss: 0.0275
#
# Epoch: 4/8
# Training Loss: 0.0334
#
# Epoch: 4/8
# Training Loss: 0.0347
#
# Epoch: 4/8
# Training Loss: 0.0282
#
# Epoch: 4/8
# Training Loss: 0.0278
#
# Epoch: 4/8
# Training Loss: 0.0300
#
# Epoch: 4/8
# Training Loss: 0.0271
#
# Epoch: 4/8
# Training Loss: 0.0249
#
# Epoch: 4/8
# Training Loss: 0.0270
#
# Epoch: 4/8
# Training Loss: 0.0276
#
# Epoch: 4/8
# Training Loss: 0.0258
#
# Epoch: 4/8
# Training Loss: 0.0272
#
# Epoch: 4/8
# Training Loss: 0.0236
#
# Epoch: 4/8
# Training Loss: 0.0215
#
# Epoch: 4/8
# Training Loss: 0.0281
#
# Epoch: 4/8
# Training Loss: 0.0247
#
# Epoch: 4/8
# Training Loss: 0.0196
#
# Epoch: 4/8
# Training Loss: 0.0208
#
# Epoch: 4/8
# Training Loss: 0.0175
#
# Epoch: 4/8
# Training Loss: 0.0178
#
# Epoch: 4/8
# Training Loss: 0.0206
#
# Epoch: 4/8
# Training Loss: 0.0197
#
# Epoch: 4/8
# Training Loss: 0.0196
#
# Epoch: 4/8
# Training Loss: 0.0219
#
# Epoch: 4/8
# Training Loss: 0.0222
#
# Epoch: 4/8
# Training Loss: 0.0175
#
# Epoch: 4/8
# Training Loss: 0.0239
#
# Epoch: 4/8
# Training Loss: 0.0202
#
# Epoch: 4/8
# Training Loss: 0.0188
#
# Epoch: 4/8
# Training Loss: 0.0192
#
# Epoch: 4/8
# Training Loss: 0.0188
#
# Epoch: 4/8
# Training Loss: 0.0167
#
# Epoch: 4/8
# Training Loss: 0.0169
#
# Epoch: 4/8
# Training Loss: 0.0180
#
# Epoch: 4/8
# Training Loss: 0.0196
#
# Epoch: 4/8
# Training Loss: 0.0169
#
# Epoch: 4/8
# Training Loss: 0.0178
#
# Epoch: 4/8
# Training Loss: 0.0174
#
# Epoch: 4/8
# Training Loss: 0.0195
#
# Epoch: 4/8
# Training Loss: 0.0189
#
# Epoch: 4/8
# Training Loss: 0.0163
#
# Epoch: 4/8
# Training Loss: 0.0179
#
# Epoch: 4/8
# Training Loss: 0.0128
# Validation Loss: 1.2361   Accuracy: 0.7500
# Validation Loss: 0.6854   Accuracy: 0.7188
# Validation Loss: 0.3827   Accuracy: 0.7344
# Validation Loss: 0.4340   Accuracy: 0.6406
# Validation Loss: 0.3281   Accuracy: 0.6250
# Validation Loss: 0.2375   Accuracy: 0.7344
# Validation Loss: 0.2046   Accuracy: 0.7500
# Validation Loss: 0.1905   Accuracy: 0.7031
# Validation Loss: 0.1574   Accuracy: 0.7188
# Validation Loss: 0.1419   Accuracy: 0.7812
# Validation Loss: 0.1240   Accuracy: 0.7188
# Validation Loss: 0.1250   Accuracy: 0.6562
# Validation Loss: 0.1186   Accuracy: 0.6400
#
# Epoch: 5/8
# Training Loss: 1.7192
#
# Epoch: 5/8
# Training Loss: 0.6758
#
# Epoch: 5/8
# Training Loss: 0.4764
#
# Epoch: 5/8
# Training Loss: 0.3959
#
# Epoch: 5/8
# Training Loss: 0.3643
#
# Epoch: 5/8
# Training Loss: 0.2465
#
# Epoch: 5/8
# Training Loss: 0.1886
#
# Epoch: 5/8
# Training Loss: 0.2168
#
# Epoch: 5/8
# Training Loss: 0.1956
#
# Epoch: 5/8
# Training Loss: 0.1481
#
# Epoch: 5/8
# Training Loss: 0.1513
#
# Epoch: 5/8
# Training Loss: 0.1702
#
# Epoch: 5/8
# Training Loss: 0.1017
#
# Epoch: 5/8
# Training Loss: 0.1129
#
# Epoch: 5/8
# Training Loss: 0.1207
#
# Epoch: 5/8
# Training Loss: 0.1074
#
# Epoch: 5/8
# Training Loss: 0.1034
#
# Epoch: 5/8
# Training Loss: 0.0822
#
# Epoch: 5/8
# Training Loss: 0.0778
#
# Epoch: 5/8
# Training Loss: 0.0740
#
# Epoch: 5/8
# Training Loss: 0.0874
#
# Epoch: 5/8
# Training Loss: 0.0753
#
# Epoch: 5/8
# Training Loss: 0.0649
#
# Epoch: 5/8
# Training Loss: 0.0670
#
# Epoch: 5/8
# Training Loss: 0.0567
#
# Epoch: 5/8
# Training Loss: 0.0558
#
# Epoch: 5/8
# Training Loss: 0.0706
#
# Epoch: 5/8
# Training Loss: 0.0469
#
# Epoch: 5/8
# Training Loss: 0.0557
#
# Epoch: 5/8
# Training Loss: 0.0565
#
# Epoch: 5/8
# Training Loss: 0.0471
#
# Epoch: 5/8
# Training Loss: 0.0527
#
# Epoch: 5/8
# Training Loss: 0.0480
#
# Epoch: 5/8
# Training Loss: 0.0453
#
# Epoch: 5/8
# Training Loss: 0.0536
#
# Epoch: 5/8
# Training Loss: 0.0464
#
# Epoch: 5/8
# Training Loss: 0.0455
#
# Epoch: 5/8
# Training Loss: 0.0389
#
# Epoch: 5/8
# Training Loss: 0.0412
#
# Epoch: 5/8
# Training Loss: 0.0397
#
# Epoch: 5/8
# Training Loss: 0.0475
#
# Epoch: 5/8
# Training Loss: 0.0420
#
# Epoch: 5/8
# Training Loss: 0.0356
#
# Epoch: 5/8
# Training Loss: 0.0391
#
# Epoch: 5/8
# Training Loss: 0.0332
#
# Epoch: 5/8
# Training Loss: 0.0399
#
# Epoch: 5/8
# Training Loss: 0.0341
#
# Epoch: 5/8
# Training Loss: 0.0338
#
# Epoch: 5/8
# Training Loss: 0.0402
#
# Epoch: 5/8
# Training Loss: 0.0289
#
# Epoch: 5/8
# Training Loss: 0.0247
#
# Epoch: 5/8
# Training Loss: 0.0282
#
# Epoch: 5/8
# Training Loss: 0.0302
#
# Epoch: 5/8
# Training Loss: 0.0278
#
# Epoch: 5/8
# Training Loss: 0.0264
#
# Epoch: 5/8
# Training Loss: 0.0321
#
# Epoch: 5/8
# Training Loss: 0.0313
#
# Epoch: 5/8
# Training Loss: 0.0280
#
# Epoch: 5/8
# Training Loss: 0.0277
#
# Epoch: 5/8
# Training Loss: 0.0251
#
# Epoch: 5/8
# Training Loss: 0.0215
#
# Epoch: 5/8
# Training Loss: 0.0299
#
# Epoch: 5/8
# Training Loss: 0.0261
#
# Epoch: 5/8
# Training Loss: 0.0199
#
# Epoch: 5/8
# Training Loss: 0.0199
#
# Epoch: 5/8
# Training Loss: 0.0282
#
# Epoch: 5/8
# Training Loss: 0.0193
#
# Epoch: 5/8
# Training Loss: 0.0212
#
# Epoch: 5/8
# Training Loss: 0.0290
#
# Epoch: 5/8
# Training Loss: 0.0251
#
# Epoch: 5/8
# Training Loss: 0.0220
#
# Epoch: 5/8
# Training Loss: 0.0209
#
# Epoch: 5/8
# Training Loss: 0.0248
#
# Epoch: 5/8
# Training Loss: 0.0259
#
# Epoch: 5/8
# Training Loss: 0.0187
#
# Epoch: 5/8
# Training Loss: 0.0198
#
# Epoch: 5/8
# Training Loss: 0.0184
#
# Epoch: 5/8
# Training Loss: 0.0168
#
# Epoch: 5/8
# Training Loss: 0.0182
#
# Epoch: 5/8
# Training Loss: 0.0181
#
# Epoch: 5/8
# Training Loss: 0.0207
#
# Epoch: 5/8
# Training Loss: 0.0168
#
# Epoch: 5/8
# Training Loss: 0.0173
#
# Epoch: 5/8
# Training Loss: 0.0160
#
# Epoch: 5/8
# Training Loss: 0.0175
#
# Epoch: 5/8
# Training Loss: 0.0165
#
# Epoch: 5/8
# Training Loss: 0.0150
#
# Epoch: 5/8
# Training Loss: 0.0181
#
# Epoch: 5/8
# Training Loss: 0.0145
#
# Epoch: 5/8
# Training Loss: 0.0167
#
# Epoch: 5/8
# Training Loss: 0.0164
#
# Epoch: 5/8
# Training Loss: 0.0159
#
# Epoch: 5/8
# Training Loss: 0.0147
#
# Epoch: 5/8
# Training Loss: 0.0173
#
# Epoch: 5/8
# Training Loss: 0.0145
#
# Epoch: 5/8
# Training Loss: 0.0185
#
# Epoch: 5/8
# Training Loss: 0.0146
#
# Epoch: 5/8
# Training Loss: 0.0140
#
# Epoch: 5/8
# Training Loss: 0.0152
#
# Epoch: 5/8
# Training Loss: 0.0146
#
# Epoch: 5/8
# Training Loss: 0.0137
#
# Epoch: 5/8
# Training Loss: 0.0139
#
# Epoch: 5/8
# Training Loss: 0.0124
# Validation Loss: 0.9720   Accuracy: 0.8125
# Validation Loss: 0.7147   Accuracy: 0.6875
# Validation Loss: 0.3557   Accuracy: 0.7031
# Validation Loss: 0.3273   Accuracy: 0.7188
# Validation Loss: 0.2775   Accuracy: 0.7188
# Validation Loss: 0.2054   Accuracy: 0.7344
# Validation Loss: 0.1969   Accuracy: 0.7344
# Validation Loss: 0.2064   Accuracy: 0.6094
# Validation Loss: 0.1315   Accuracy: 0.7188
# Validation Loss: 0.1244   Accuracy: 0.7188
# Validation Loss: 0.1157   Accuracy: 0.6875
# Validation Loss: 0.1383   Accuracy: 0.6562
# Validation Loss: 0.0941   Accuracy: 0.7400
#
# Epoch: 6/8
# Training Loss: 1.4561
#
# Epoch: 6/8
# Training Loss: 0.7442
#
# Epoch: 6/8
# Training Loss: 0.5348
#
# Epoch: 6/8
# Training Loss: 0.3751
#
# Epoch: 6/8
# Training Loss: 0.3369
#
# Epoch: 6/8
# Training Loss: 0.2998
#
# Epoch: 6/8
# Training Loss: 0.1803
#
# Epoch: 6/8
# Training Loss: 0.1399
#
# Epoch: 6/8
# Training Loss: 0.1527
#
# Epoch: 6/8
# Training Loss: 0.1481
#
# Epoch: 6/8
# Training Loss: 0.1206
#
# Epoch: 6/8
# Training Loss: 0.1314
#
# Epoch: 6/8
# Training Loss: 0.1118
#
# Epoch: 6/8
# Training Loss: 0.1000
#
# Epoch: 6/8
# Training Loss: 0.0786
#
# Epoch: 6/8
# Training Loss: 0.0856
#
# Epoch: 6/8
# Training Loss: 0.0888
#
# Epoch: 6/8
# Training Loss: 0.0776
#
# Epoch: 6/8
# Training Loss: 0.0694
#
# Epoch: 6/8
# Training Loss: 0.0579
#
# Epoch: 6/8
# Training Loss: 0.0655
#
# Epoch: 6/8
# Training Loss: 0.0739
#
# Epoch: 6/8
# Training Loss: 0.0736
#
# Epoch: 6/8
# Training Loss: 0.0738
#
# Epoch: 6/8
# Training Loss: 0.0643
#
# Epoch: 6/8
# Training Loss: 0.0569
#
# Epoch: 6/8
# Training Loss: 0.0441
#
# Epoch: 6/8
# Training Loss: 0.0586
#
# Epoch: 6/8
# Training Loss: 0.0513
#
# Epoch: 6/8
# Training Loss: 0.0455
#
# Epoch: 6/8
# Training Loss: 0.0454
#
# Epoch: 6/8
# Training Loss: 0.0384
#
# Epoch: 6/8
# Training Loss: 0.0381
#
# Epoch: 6/8
# Training Loss: 0.0409
#
# Epoch: 6/8
# Training Loss: 0.0389
#
# Epoch: 6/8
# Training Loss: 0.0385
#
# Epoch: 6/8
# Training Loss: 0.0445
#
# Epoch: 6/8
# Training Loss: 0.0433
#
# Epoch: 6/8
# Training Loss: 0.0372
#
# Epoch: 6/8
# Training Loss: 0.0305
#
# Epoch: 6/8
# Training Loss: 0.0324
#
# Epoch: 6/8
# Training Loss: 0.0360
#
# Epoch: 6/8
# Training Loss: 0.0286
#
# Epoch: 6/8
# Training Loss: 0.0308
#
# Epoch: 6/8
# Training Loss: 0.0311
#
# Epoch: 6/8
# Training Loss: 0.0316
#
# Epoch: 6/8
# Training Loss: 0.0183
#
# Epoch: 6/8
# Training Loss: 0.0286
#
# Epoch: 6/8
# Training Loss: 0.0208
#
# Epoch: 6/8
# Training Loss: 0.0343
#
# Epoch: 6/8
# Training Loss: 0.0308
#
# Epoch: 6/8
# Training Loss: 0.0297
#
# Epoch: 6/8
# Training Loss: 0.0307
#
# Epoch: 6/8
# Training Loss: 0.0274
#
# Epoch: 6/8
# Training Loss: 0.0279
#
# Epoch: 6/8
# Training Loss: 0.0273
#
# Epoch: 6/8
# Training Loss: 0.0237
#
# Epoch: 6/8
# Training Loss: 0.0243
#
# Epoch: 6/8
# Training Loss: 0.0229
#
# Epoch: 6/8
# Training Loss: 0.0251
#
# Epoch: 6/8
# Training Loss: 0.0239
#
# Epoch: 6/8
# Training Loss: 0.0207
#
# Epoch: 6/8
# Training Loss: 0.0223
#
# Epoch: 6/8
# Training Loss: 0.0232
#
# Epoch: 6/8
# Training Loss: 0.0178
#
# Epoch: 6/8
# Training Loss: 0.0201
#
# Epoch: 6/8
# Training Loss: 0.0205
#
# Epoch: 6/8
# Training Loss: 0.0208
#
# Epoch: 6/8
# Training Loss: 0.0190
#
# Epoch: 6/8
# Training Loss: 0.0199
#
# Epoch: 6/8
# Training Loss: 0.0172
#
# Epoch: 6/8
# Training Loss: 0.0217
#
# Epoch: 6/8
# Training Loss: 0.0189
#
# Epoch: 6/8
# Training Loss: 0.0182
#
# Epoch: 6/8
# Training Loss: 0.0204
#
# Epoch: 6/8
# Training Loss: 0.0171
#
# Epoch: 6/8
# Training Loss: 0.0189
#
# Epoch: 6/8
# Training Loss: 0.0164
#
# Epoch: 6/8
# Training Loss: 0.0148
#
# Epoch: 6/8
# Training Loss: 0.0234
#
# Epoch: 6/8
# Training Loss: 0.0172
#
# Epoch: 6/8
# Training Loss: 0.0193
#
# Epoch: 6/8
# Training Loss: 0.0166
#
# Epoch: 6/8
# Training Loss: 0.0156
#
# Epoch: 6/8
# Training Loss: 0.0194
#
# Epoch: 6/8
# Training Loss: 0.0140
#
# Epoch: 6/8
# Training Loss: 0.0170
#
# Epoch: 6/8
# Training Loss: 0.0168
#
# Epoch: 6/8
# Training Loss: 0.0144
#
# Epoch: 6/8
# Training Loss: 0.0142
#
# Epoch: 6/8
# Training Loss: 0.0126
#
# Epoch: 6/8
# Training Loss: 0.0148
#
# Epoch: 6/8
# Training Loss: 0.0123
#
# Epoch: 6/8
# Training Loss: 0.0137
#
# Epoch: 6/8
# Training Loss: 0.0125
#
# Epoch: 6/8
# Training Loss: 0.0160
#
# Epoch: 6/8
# Training Loss: 0.0147
#
# Epoch: 6/8
# Training Loss: 0.0147
#
# Epoch: 6/8
# Training Loss: 0.0154
#
# Epoch: 6/8
# Training Loss: 0.0133
#
# Epoch: 6/8
# Training Loss: 0.0112
#
# Epoch: 6/8
# Training Loss: 0.0140
# Validation Loss: 1.0478   Accuracy: 0.7812
# Validation Loss: 0.6022   Accuracy: 0.7500
# Validation Loss: 0.3391   Accuracy: 0.7500
# Validation Loss: 0.3489   Accuracy: 0.6094
# Validation Loss: 0.2320   Accuracy: 0.7344
# Validation Loss: 0.2296   Accuracy: 0.6250
# Validation Loss: 0.1626   Accuracy: 0.6719
# Validation Loss: 0.1401   Accuracy: 0.7188
# Validation Loss: 0.1433   Accuracy: 0.6719
# Validation Loss: 0.1180   Accuracy: 0.6875
# Validation Loss: 0.1212   Accuracy: 0.7031
# Validation Loss: 0.0892   Accuracy: 0.7188
# Validation Loss: 0.0875   Accuracy: 0.6800
#
# Epoch: 7/8
# Training Loss: 1.3787
#
# Epoch: 7/8
# Training Loss: 0.7065
#
# Epoch: 7/8
# Training Loss: 0.4351
#
# Epoch: 7/8
# Training Loss: 0.4040
#
# Epoch: 7/8
# Training Loss: 0.3552
#
# Epoch: 7/8
# Training Loss: 0.2308
#
# Epoch: 7/8
# Training Loss: 0.1943
#
# Epoch: 7/8
# Training Loss: 0.1403
#
# Epoch: 7/8
# Training Loss: 0.1497
#
# Epoch: 7/8
# Training Loss: 0.1392
#
# Epoch: 7/8
# Training Loss: 0.1342
#
# Epoch: 7/8
# Training Loss: 0.1107
#
# Epoch: 7/8
# Training Loss: 0.1269
#
# Epoch: 7/8
# Training Loss: 0.1045
#
# Epoch: 7/8
# Training Loss: 0.0883
#
# Epoch: 7/8
# Training Loss: 0.0773
#
# Epoch: 7/8
# Training Loss: 0.0826
#
# Epoch: 7/8
# Training Loss: 0.0597
#
# Epoch: 7/8
# Training Loss: 0.0663
#
# Epoch: 7/8
# Training Loss: 0.0699
#
# Epoch: 7/8
# Training Loss: 0.0521
#
# Epoch: 7/8
# Training Loss: 0.0502
#
# Epoch: 7/8
# Training Loss: 0.0614
#
# Epoch: 7/8
# Training Loss: 0.0519
#
# Epoch: 7/8
# Training Loss: 0.0461
#
# Epoch: 7/8
# Training Loss: 0.0484
#
# Epoch: 7/8
# Training Loss: 0.0511
#
# Epoch: 7/8
# Training Loss: 0.0507
#
# Epoch: 7/8
# Training Loss: 0.0445
#
# Epoch: 7/8
# Training Loss: 0.0480
#
# Epoch: 7/8
# Training Loss: 0.0398
#
# Epoch: 7/8
# Training Loss: 0.0372
#
# Epoch: 7/8
# Training Loss: 0.0459
#
# Epoch: 7/8
# Training Loss: 0.0371
#
# Epoch: 7/8
# Training Loss: 0.0393
#
# Epoch: 7/8
# Training Loss: 0.0343
#
# Epoch: 7/8
# Training Loss: 0.0405
#
# Epoch: 7/8
# Training Loss: 0.0434
#
# Epoch: 7/8
# Training Loss: 0.0349
#
# Epoch: 7/8
# Training Loss: 0.0297
#
# Epoch: 7/8
# Training Loss: 0.0292
#
# Epoch: 7/8
# Training Loss: 0.0322
#
# Epoch: 7/8
# Training Loss: 0.0337
#
# Epoch: 7/8
# Training Loss: 0.0313
#
# Epoch: 7/8
# Training Loss: 0.0256
#
# Epoch: 7/8
# Training Loss: 0.0265
#
# Epoch: 7/8
# Training Loss: 0.0287
#
# Epoch: 7/8
# Training Loss: 0.0286
#
# Epoch: 7/8
# Training Loss: 0.0216
#
# Epoch: 7/8
# Training Loss: 0.0255
#
# Epoch: 7/8
# Training Loss: 0.0261
#
# Epoch: 7/8
# Training Loss: 0.0229
#
# Epoch: 7/8
# Training Loss: 0.0302
#
# Epoch: 7/8
# Training Loss: 0.0264
#
# Epoch: 7/8
# Training Loss: 0.0240
#
# Epoch: 7/8
# Training Loss: 0.0258
#
# Epoch: 7/8
# Training Loss: 0.0269
#
# Epoch: 7/8
# Training Loss: 0.0253
#
# Epoch: 7/8
# Training Loss: 0.0234
#
# Epoch: 7/8
# Training Loss: 0.0270
#
# Epoch: 7/8
# Training Loss: 0.0191
#
# Epoch: 7/8
# Training Loss: 0.0229
#
# Epoch: 7/8
# Training Loss: 0.0250
#
# Epoch: 7/8
# Training Loss: 0.0240
#
# Epoch: 7/8
# Training Loss: 0.0213
#
# Epoch: 7/8
# Training Loss: 0.0160
#
# Epoch: 7/8
# Training Loss: 0.0194
#
# Epoch: 7/8
# Training Loss: 0.0150
#
# Epoch: 7/8
# Training Loss: 0.0165
#
# Epoch: 7/8
# Training Loss: 0.0190
#
# Epoch: 7/8
# Training Loss: 0.0213
#
# Epoch: 7/8
# Training Loss: 0.0167
#
# Epoch: 7/8
# Training Loss: 0.0168
#
# Epoch: 7/8
# Training Loss: 0.0205
#
# Epoch: 7/8
# Training Loss: 0.0154
#
# Epoch: 7/8
# Training Loss: 0.0162
#
# Epoch: 7/8
# Training Loss: 0.0160
#
# Epoch: 7/8
# Training Loss: 0.0188
#
# Epoch: 7/8
# Training Loss: 0.0154
#
# Epoch: 7/8
# Training Loss: 0.0210
#
# Epoch: 7/8
# Training Loss: 0.0162
#
# Epoch: 7/8
# Training Loss: 0.0163
#
# Epoch: 7/8
# Training Loss: 0.0148
#
# Epoch: 7/8
# Training Loss: 0.0145
#
# Epoch: 7/8
# Training Loss: 0.0184
#
# Epoch: 7/8
# Training Loss: 0.0122
#
# Epoch: 7/8
# Training Loss: 0.0136
#
# Epoch: 7/8
# Training Loss: 0.0157
#
# Epoch: 7/8
# Training Loss: 0.0130
#
# Epoch: 7/8
# Training Loss: 0.0149
#
# Epoch: 7/8
# Training Loss: 0.0161
#
# Epoch: 7/8
# Training Loss: 0.0105
#
# Epoch: 7/8
# Training Loss: 0.0124
#
# Epoch: 7/8
# Training Loss: 0.0140
#
# Epoch: 7/8
# Training Loss: 0.0100
#
# Epoch: 7/8
# Training Loss: 0.0160
#
# Epoch: 7/8
# Training Loss: 0.0114
#
# Epoch: 7/8
# Training Loss: 0.0114
#
# Epoch: 7/8
# Training Loss: 0.0137
#
# Epoch: 7/8
# Training Loss: 0.0114
#
# Epoch: 7/8
# Training Loss: 0.0119
#
# Epoch: 7/8
# Training Loss: 0.0134
#
# Epoch: 7/8
# Training Loss: 0.0113
# Validation Loss: 1.0189   Accuracy: 0.7656
# Validation Loss: 0.5235   Accuracy: 0.7500
# Validation Loss: 0.3355   Accuracy: 0.7812
# Validation Loss: 0.2488   Accuracy: 0.7812
# Validation Loss: 0.2482   Accuracy: 0.6719
# Validation Loss: 0.1549   Accuracy: 0.7812
# Validation Loss: 0.1520   Accuracy: 0.7031
# Validation Loss: 0.1367   Accuracy: 0.7500
# Validation Loss: 0.1302   Accuracy: 0.7656
# Validation Loss: 0.1019   Accuracy: 0.7812
# Validation Loss: 0.0996   Accuracy: 0.7500
# Validation Loss: 0.0831   Accuracy: 0.7812
# Validation Loss: 0.0811   Accuracy: 0.8200
#
# Epoch: 8/8
# Training Loss: 1.2252
#
# Epoch: 8/8
# Training Loss: 0.7655
#
# Epoch: 8/8
# Training Loss: 0.4009
#
# Epoch: 8/8
# Training Loss: 0.2817
#
# Epoch: 8/8
# Training Loss: 0.2423
#
# Epoch: 8/8
# Training Loss: 0.2763
#
# Epoch: 8/8
# Training Loss: 0.1729
#
# Epoch: 8/8
# Training Loss: 0.1361
#
# Epoch: 8/8
# Training Loss: 0.1275
#
# Epoch: 8/8
# Training Loss: 0.1093
#
# Epoch: 8/8
# Training Loss: 0.0940
#
# Epoch: 8/8
# Training Loss: 0.1006
#
# Epoch: 8/8
# Training Loss: 0.0893
#
# Epoch: 8/8
# Training Loss: 0.0909
#
# Epoch: 8/8
# Training Loss: 0.0772
#
# Epoch: 8/8
# Training Loss: 0.0802
#
# Epoch: 8/8
# Training Loss: 0.0633
#
# Epoch: 8/8
# Training Loss: 0.0811
#
# Epoch: 8/8
# Training Loss: 0.0737
#
# Epoch: 8/8
# Training Loss: 0.0633
#
# Epoch: 8/8
# Training Loss: 0.0628
#
# Epoch: 8/8
# Training Loss: 0.0517
#
# Epoch: 8/8
# Training Loss: 0.0538
#
# Epoch: 8/8
# Training Loss: 0.0480
#
# Epoch: 8/8
# Training Loss: 0.0324
#
# Epoch: 8/8
# Training Loss: 0.0553
#
# Epoch: 8/8
# Training Loss: 0.0351
#
# Epoch: 8/8
# Training Loss: 0.0404
#
# Epoch: 8/8
# Training Loss: 0.0426
#
# Epoch: 8/8
# Training Loss: 0.0464
#
# Epoch: 8/8
# Training Loss: 0.0325
#
# Epoch: 8/8
# Training Loss: 0.0343
#
# Epoch: 8/8
# Training Loss: 0.0330
#
# Epoch: 8/8
# Training Loss: 0.0287
#
# Epoch: 8/8
# Training Loss: 0.0503
#
# Epoch: 8/8
# Training Loss: 0.0315
#
# Epoch: 8/8
# Training Loss: 0.0347
#
# Epoch: 8/8
# Training Loss: 0.0296
#
# Epoch: 8/8
# Training Loss: 0.0288
#
# Epoch: 8/8
# Training Loss: 0.0324
#
# Epoch: 8/8
# Training Loss: 0.0379
#
# Epoch: 8/8
# Training Loss: 0.0305
#
# Epoch: 8/8
# Training Loss: 0.0293
#
# Epoch: 8/8
# Training Loss: 0.0309
#
# Epoch: 8/8
# Training Loss: 0.0275
#
# Epoch: 8/8
# Training Loss: 0.0312
#
# Epoch: 8/8
# Training Loss: 0.0286
#
# Epoch: 8/8
# Training Loss: 0.0210
#
# Epoch: 8/8
# Training Loss: 0.0272
#
# Epoch: 8/8
# Training Loss: 0.0255
#
# Epoch: 8/8
# Training Loss: 0.0226
#
# Epoch: 8/8
# Training Loss: 0.0187
#
# Epoch: 8/8
# Training Loss: 0.0205
#
# Epoch: 8/8
# Training Loss: 0.0189
#
# Epoch: 8/8
# Training Loss: 0.0220
#
# Epoch: 8/8
# Training Loss: 0.0213
#
# Epoch: 8/8
# Training Loss: 0.0172
#
# Epoch: 8/8
# Training Loss: 0.0178
#
# Epoch: 8/8
# Training Loss: 0.0182
#
# Epoch: 8/8
# Training Loss: 0.0182
#
# Epoch: 8/8
# Training Loss: 0.0206
#
# Epoch: 8/8
# Training Loss: 0.0194
#
# Epoch: 8/8
# Training Loss: 0.0183
#
# Epoch: 8/8
# Training Loss: 0.0178
#
# Epoch: 8/8
# Training Loss: 0.0166
#
# Epoch: 8/8
# Training Loss: 0.0238
#
# Epoch: 8/8
# Training Loss: 0.0111
#
# Epoch: 8/8
# Training Loss: 0.0178
#
# Epoch: 8/8
# Training Loss: 0.0170
#
# Epoch: 8/8
# Training Loss: 0.0181
#
# Epoch: 8/8
# Training Loss: 0.0207
#
# Epoch: 8/8
# Training Loss: 0.0164
#
# Epoch: 8/8
# Training Loss: 0.0183
#
# Epoch: 8/8
# Training Loss: 0.0164
#
# Epoch: 8/8
# Training Loss: 0.0175
#
# Epoch: 8/8
# Training Loss: 0.0155
#
# Epoch: 8/8
# Training Loss: 0.0187
#
# Epoch: 8/8
# Training Loss: 0.0131
#
# Epoch: 8/8
# Training Loss: 0.0154
#
# Epoch: 8/8
# Training Loss: 0.0174
#
# Epoch: 8/8
# Training Loss: 0.0155
#
# Epoch: 8/8
# Training Loss: 0.0174
#
# Epoch: 8/8
# Training Loss: 0.0122
#
# Epoch: 8/8
# Training Loss: 0.0112
#
# Epoch: 8/8
# Training Loss: 0.0102
#
# Epoch: 8/8
# Training Loss: 0.0147
#
# Epoch: 8/8
# Training Loss: 0.0131
#
# Epoch: 8/8
# Training Loss: 0.0143
#
# Epoch: 8/8
# Training Loss: 0.0135
#
# Epoch: 8/8
# Training Loss: 0.0140
#
# Epoch: 8/8
# Training Loss: 0.0101
#
# Epoch: 8/8
# Training Loss: 0.0131
#
# Epoch: 8/8
# Training Loss: 0.0113
#
# Epoch: 8/8
# Training Loss: 0.0128
#
# Epoch: 8/8
# Training Loss: 0.0120
#
# Epoch: 8/8
# Training Loss: 0.0156
#
# Epoch: 8/8
# Training Loss: 0.0152
#
# Epoch: 8/8
# Training Loss: 0.0113
#
# Epoch: 8/8
# Training Loss: 0.0111
#
# Epoch: 8/8
# Training Loss: 0.0120
#
# Epoch: 8/8
# Training Loss: 0.0115
#
# Epoch: 8/8
# Training Loss: 0.0121
#
# Epoch: 8/8
# Training Loss: 0.0122
# Validation Loss: 1.1982   Accuracy: 0.7344
# Validation Loss: 0.3630   Accuracy: 0.7812
# Validation Loss: 0.3296   Accuracy: 0.8125
# Validation Loss: 0.2296   Accuracy: 0.7656
# Validation Loss: 0.1645   Accuracy: 0.8594
# Validation Loss: 0.2339   Accuracy: 0.6250
# Validation Loss: 0.1182   Accuracy: 0.7344
# Validation Loss: 0.1614   Accuracy: 0.6406
# Validation Loss: 0.1297   Accuracy: 0.7188
# Validation Loss: 0.0877   Accuracy: 0.7812
# Validation Loss: 0.0818   Accuracy: 0.7969
# Validation Loss: 0.0782   Accuracy: 0.7969
# Validation Loss: 0.0805   Accuracy: 0.7400
#
# Total time: 22m 51s

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
model.eval()
accuracy = 0

for data in dataloaders[mode]:
    pass_count += 1
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)
    outputs = model(inputs)
            
    # Class with the highest probability is our predicted class
    equality = (labels.data == outputs.max(1)[1])
    # Accuracy is number of correct predictions divided by all predictions
    accuracy += equality.type_as(torch.FloatTensor()).mean()
    
print("Test accuracy: {:.3f}".format(accuracy/len(dataloaders[mode])))
# Out:
# Test accuracy: 0.773

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 

#model.class_to_idx = image_datasets[0].class_to_idx
model.class_to_idx = image_datasets[0].class_to_idx

checkpoint = {'input_size': 1024,
              'output_size': 2,
              'arch': 'vgg19',
              'learning_rate': 0.01,
              'batch_size': 64,
              'classifier' : classifier,
              'epochs': epochs,
              'optimizer': optimizer.state_dict(),
              'state_dict': model.state_dict(),
              'class_to_idx': model.class_to_idx}

torch.save(checkpoint, 'checkpoint.pth')
print("saved checkpoint")
# Out:
# saved checkpoint

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filename):
    checkpoint = torch.load(filename)
    learning_rate = checkpoint['learning_rate']
    model = getattr(torchvision.models, checkpoint['arch'](pretrained=True))
    model.classifier = checkpoint['classifier']
    model.epochs = checkpoint['epochs']
    model.load_state_dic(checkpoint['state_dic'])
    model.class_to_idx = checkpoint['class_to_idx']
    optimizer.load_state_dic(checkpoint['optimizer'])
    
    return model, optimizer

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
    import PIL
    from PIL import Image
    

    load_img = transforms.Compose([
        transforms.Resize(256), 
        transforms.CenterCrop(224), 
        transforms.ToTensor()])
    
    pil_image = Image.open(image).transforms.resize(256, 256)
    pil_images = load_img(pil_image).float()
    
    np_image = np.array(pil_images) 
    
    mean_network = np.array([0.485, 0.456, 0.406])
    std_network = np.array([0.229, 0.224, 0.225])
    np_image = (np.transpose(np_image, (1, 2, 0)) - mean_network)/std_network    
    np_image = np.transpose(np_image, (2, 0, 1))
            
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    
    def imshow(image, ax=None, title=None):
        if ax is None:
            fig, ax = plt.subplots()
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    ax.imshow(image)
    return ax

# Show original picture
img = random.choice(os.listdir('./flowers/test/7/'))
img_path = './flowers/test/7/' + img

with Image.open(img_path) as image:
    plt.imshow(image)
    
model.class_to_idx = image_datasets[0].class_to_idx

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
 
    # TODO: Implement the code to predict the class from an image file
    # move the model to cuda
    cuda = torch.cuda.is_available()
    if cuda:
        # Move model parameters to the GPU
        model.cuda()
        print("Number of GPUs:", torch.cuda.device_count())
        print("Device name:", torch.cuda.get_device_name(torch.cuda.device_count()-1))
    else:
        model.cpu()
        print("We go for CPU")
    
    # turn off dropout
    model.eval()

    # The image
    image = process_image(image_path)
    
    # tranfer to tensor
    image = torch.from_numpy(np.array([image])).float()
    
    # The image becomes the input
    image = Variable(image)
    if cuda:
        image = image.cuda()
        
    output = model.forward(image)
    
    probabilities = torch.exp(output).data
    
    # getting the topk (=5) probabilites and indexes
    # 0 -> probabilities
    # 1 -> index
    prob = torch.topk(probabilities, topk)[0].tolist()[0] # probabilities
    index = torch.topk(probabilities, topk)[1].tolist()[0] # index
    
    ind = []
    for i in range(len(model.class_to_idx.items())):
        ind.append(list(model.class_to_idx.items())[i][0])

    # transfer index to label
    label = []
    for i in range(5):
        label.append(ind[index[i]])

    return prob, label
'''
    img = Image.open(image_path)
    img = process_image(img)
    
    # Convert to 1D vector
    img = np.expand_dims(img, 0)
    
    
    img = torch.from_numpy(img)
    
    model.eval()
    inputs = Variable(img).to(device)
    logits = model.forward(inputs)
    
    ps = F.softmax(logits,dim=1)
    topk = ps.cpu().topk(topk)
    
    return (e.data.numpy().squeeze().tolist() for e in topk)

   '''
# Out:
# '\n    img = Image.open(image_path)\n    img = process_image(img)\n    \n    # Convert to 1D vector\n    img = np.expand_dims(img, 0)\n    \n    \n    img = torch.from_numpy(img)\n    \n    model.eval()\n    inputs = Variable(img).to(device)\n    logits = model.forward(inputs)\n    \n    ps = F.softmax(logits,dim=1)\n    topk = ps.cpu().topk(topk)\n    \n    return (e.data.numpy().squeeze().tolist() for e in topk)\n\n   '

# %%
import random
import os 
img = random.choice(os.listdir('./flowers/test/7/'))
img_path = './flowers/test/7/' + img
with  Image.open(img_path) as image:
    plt.imshow(image)

mmodel = model.to(device)    
prob, classes = predict(img_path, mmodel)

print(prob)
print(classes)
flower_names = [cat_to_name[class_names[e]] for e in classes]
print(flower_names)
# Out:
# Number of GPUs: 1
# Device name: Tesla K80
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-91f2a6ddb206> in <module>()
#       7
#       8 mmodel = model.to(device)
# ----> 9 prob, classes = predict(img_path, mmodel)
#      10
#      11 print(prob)
#
# <ipython-input-84-6c63714ec96e> in predict(image_path, model, topk)
#      21
#      22     # The image
# ---> 23     image = process_image(image_path)
#      24
#      25     # tranfer to tensor
#
# <ipython-input-82-4af3fb4b21ff> in process_image(image)
#      13         transforms.ToTensor()])
#      14
# ---> 15     pil_image = Image.open(image).transforms.resize(256, 256)
#      16     pil_images = load_img(pil_image).float()
#      17
#
# AttributeError: 'JpegImageFile' object has no attribute 'transforms'

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

def view_classify(img_path, prob, classes, mapping):
    image = Image.open(img_names)
    
    fig, (ax1, ax2) = plt.subplot(figsize=(6,10), ncols=1, nrow=2)
    flower_name = mapping(img_path.split('/')[-2])
    ax1.set(title(flower_name))
    ax1.imshow(image)
    ax1.axis('off')
    
    y_pos = np.arange(len(prob))
    ax2.barh(y_pos, prob, align='center')
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels(flower_names)
    ax2.invert_yaxis()
    ax2.set_title('Class Probability')
    
    view_classify(img_path, probs, classes, cat_to_name)

# %%
# !!jupyter nbconvert *.ipynb
